# %%
import os
import pandas as pd
import numpy as np

import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

from dotenv import load_dotenv
from sqlalchemy import create_engine

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/stuartperry/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# get db connection
load_dotenv()
db_connection = os.getenv("KICKSTARTER_DB_URL")

# init database engine
engine = create_engine(db_connection)

# %%
# Query the database for text data, include only blurbs that have a majority of english language.
query = """
        SELECT  blurb, country, name, slug, state
        FROM kickstarters
        WHERE country in ('US', 'GB', 'CA', 'AU', 'NZ', 'JP', 'SG', 'PL', 'NL', 'IE', 'GR', 'AT')
        """
        #     
text_data = pd.read_sql(query, engine)

# drop na values
text_data = text_data.dropna().reset_index(drop=True)
text_data.head()
# Out:
#                                                blurb country  \
# 0  A cookbook for lyke minded poeple who love sim...      US
# 1  A Chef's Guide to Hunting, Preparing and Cooki...      US
# 2  A selection of the recipes we love from the co...      GB
# 3  A Book Where Interesting Food Things Happen: 1...      CA
# 4  Learn the homestead kitchen skills you need to...      AU
#
#                                                 name  \
# 0                               Lyke Minded Cookbook
# 1                    The Hog Book by Jesse Griffiths
# 2                   Gloria & Lil's: the recipe book.
# 3                             The Depanneur Cookbook
# 4  Real Food Cookbook: A Year in an Off-Grid Kitchen
#
#                                                slug       state
# 0                              lyke-minded-cookbook  successful
# 1                   the-hog-book-by-jesse-griffiths  successful
# 2                   gloria-and-lils-the-recipe-book  successful
# 3                            the-depanneur-cookbook  successful
# 4  real-food-cookbook-a-year-in-an-off-grid-kitchen  successful

# %%
# init analyzer and calculate sentiment scores for each blurb
analyzer = SentimentIntensityAnalyzer()
text_data['sentiment'] = text_data['blurb'].apply(analyzer.polarity_scores)

# unpack dict in rows into df concat unpacked sentiment scores to original dataframe
sentiment = pd.json_normalize(text_data['sentiment']).set_index(text_data.index)
text_data = pd.concat([text_data, sentiment], axis=1, join='inner').drop(columns=['sentiment'])
text_data.head()
# Out:
#                                                blurb country  \
# 0  A cookbook for lyke minded poeple who love sim...      US
# 1  A Chef's Guide to Hunting, Preparing and Cooki...      US
# 2  A selection of the recipes we love from the co...      GB
# 3  A Book Where Interesting Food Things Happen: 1...      CA
# 4  Learn the homestead kitchen skills you need to...      AU
#
#                                                 name  \
# 0                               Lyke Minded Cookbook
# 1                    The Hog Book by Jesse Griffiths
# 2                   Gloria & Lil's: the recipe book.
# 3                             The Depanneur Cookbook
# 4  Real Food Cookbook: A Year in an Off-Grid Kitchen
#
#                                                slug       state  neg    neu  \
# 0                              lyke-minded-cookbook  successful  0.0  0.595
# 1                   the-hog-book-by-jesse-griffiths  successful  0.0  1.000
# 2                   gloria-and-lils-the-recipe-book  successful  0.0  0.769
# 3                            the-depanneur-cookbook  successful  0.0  0.787
# 4  real-food-cookbook-a-year-in-an-off-grid-kitchen  successful  0.0  1.000
#
#      pos  compound
# 0  0.405    0.8720
# 1  0.000    0.0000
# 2  0.231    0.6369
# 3  0.213    0.4019
# 4  0.000    0.0000
